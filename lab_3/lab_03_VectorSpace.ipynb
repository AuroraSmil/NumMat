# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../styles/tma4215.css", "r").read()
    return HTML(styles)

# Comment out next line and execute this cell to restore the default notebook style 
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'> <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'> <link href="https://fonts.googleapis.com/css?family=News+Cycle" rel="stylesheet"> <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'> <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'> <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'> <link href="https://fonts.googleapis.com/css?family=Source+Code+Pro" rel="stylesheet"> <style> @font-face {
#     /*font-family: "Computer Modern";*/
#     /*src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');*/
#     font-family: 'News Cycle', sans-serif;
# }
#
#
# /* main background */
#
# ...

# %% [markdown]
# ## Problem 1
#
# In this problem we will look at the space of real polynomials of degree $\leq n$:
#
# $$
# \mathbb{P}_n(\mathbb{R}) = \left\{f: \mathbb{R}\to\mathbb{R} \quad\biggr\rvert\quad f(x) = \sum_{k=0}^n a_k x^k \quad \textrm{for some }a_1, ..., a_n \in \mathbb{R}\right\}.
# $$
# Note that each point in the space is a function, namely a polynomial.
# ### a)
# Write down the definition of a real vector space.
#
# <font color ='blue'>
#     Solution:
# </font>
#   A real vector space is a set $V$ endowed with operations addition and scalar multiplication, where these operations satisfy the following properties:
#
# 1. Commutativity: $u + v = v + u$ for all $u, v \in V$ and $(\lambda \mu)v = \lambda (\mu v)$ for all $\lambda, \mu \in \mathbb{R}$
# 2. Associativity: $(u + v) + w = u + (v + w)$ for all $u, v, w \in V$
# 3. Additive identity: There exists an element $0 \in V$ such that $0 + v = v$
# for all $v \in V$
# 4. Additive inverse: For every $v \in V$, there exists an element $w \in V$
# such that $v + w = 0$
# 5. Multiplicative identity: $1v = v$ for all $v \in V$
# 6. Distributivity: $\lambda(u + v) = \lambda u + \lambda v$ and $(\lambda + \mu)u = \lambda u + \mu u$ for all $u, v \in V$ and $\lambda, \mu ∈ \mathbb{R}$

# %% [markdown]
# ### b)
#
# Show that $\mathbb{P}_n(\mathbb{R})$ is a real vector space.
#
# *Hint: Recall the how we define adding two function, and how we define multiplying with a scalar.*
#
# <font color ='blue'>
#     Solution:
#
# </font>
# The operation of addition and multiplication in the space of real polynomials is defined coefficient-wise. For $p(x) = a_0 + a_1 x + ... + a_n x^n$ and $q(x) = b_0 + b_1 x + ... + b_n x^n$, $a_0, a_1, ... , a_n, b_0, b_1, ... , b_n \in \mathbb{R}$ , we define
# $$ (p + q) (x) = (a_0 + b_0) + (a_1 + b_1) x + ... + (a_n + b_n) x^n $$ and $$ (\lambda p) (x) = \lambda a_0 + \lambda a_1 x + ... + \lambda a_n x^n, \lambda \in \mathbb{R}$$
#
# As we are simply dealing with real numbers, we can easily see that $\mathbb{P}_n(\mathbb{R})$ satisfies all the properties listed above.

# %% [markdown]
# ### c)
#
# Show that $\mathbb{P}_n(\mathbb{R})$ has dimension $n+1$.
#
# *Hint 1: Find a set of polynomials you think is a basis for $\mathbb{P}_n(\mathbb{R})$. Verify that it is in fact a basis.*
#
# *Hint 2: If $p \in \mathbb{P}_n(\mathbb{R})$ and $p \neq 0$, how many roots can $p$ have at most? Recall the fundamental theorem of algebra.*
#
#
# <font color ='blue'>
#     Solution:
#
#
# </font>

# %% [markdown]
# First, check if the set of polynomials $\{1, x, x^2, ..., x^n\}$ is a basis for $\mathbb{P}_n(\mathbb{R})$.
# The polynomials are clearly linearly independent, since $c_0\cdot 1 + c_1x + c_2x^2 + ... + c_n x^n = 0$ only for $c_0 = c_1 = c_2 = ... = c_n = 0$. Given an arbitrary polynomial $p\in\mathbb{P}_n(\mathbb{R})$, where $p(x) = a_0 + a_1x+a_2x^2 + ... + a_nx^n$, it is clear that this polynomial can be represented as a linear combination of the proposed basis with the constants $c_i = a_i$. Hence the proposed set is a basis for  $\mathbb{P}_n(\mathbb{R})$.
#
# BRUKTE IKKE 2. HINT UPS

# %% [markdown]
# ### d)
# Write down the definition of a norm on a vector space.
#
# <font color ='blue'>
#     Solution:
# </font>
#
# A *norm* on a vector space $X$ is a function $\|\,.\| : X \to \mathbb{R}$, such that for all $x,y\in\mathbb{R}$:
#
# 1. *Positivity:* $0 \leq \|x\| \leq\infty$ and $\|x\| = 0$ if and only if $x=0$.
# 2. *Homogenity:* $\|\alpha x\| = |\alpha|\|x\|$ for any $\alpha\in\mathbb{C}$.
# 3. *Triangle inequality:* $\|x + y\| \leq \|x\| + \|y\|$

# %% [markdown]
# ### e)
# Let $x_0,...,x_n$ be $n+1$ different real numbers. For a polynomial $q \in \mathbb{P}_n(\mathbb{R})$ we now define
# $$
# \|q\|_P := \sum_{k=0}^n|q(x_k)|.
# $$
# Show that $\|\cdot\|_P$ is a norm on $\mathbb{P}_n(\mathbb{R}).$
#
#
#
# <font color ='blue'>
#     Solution:
#
# </font>

# %% [markdown]
# Let $p, q \in\mathbb{P}_n(\mathbb{R})$.
#
# *Positivity*
#
# Since the norm defined above is a sum of absolute values, the norm is always a positive number. If the polynomial $q(x)$ is the null element, so $q(x)=0$, we se that the norm is also zero. From the other side, if we have $\|q\| =0$ for a arbitrary polynomial $q$, we must have $q(x_i)=0$ for $i=0, 1, ...,n$. From the fundamental theorem of algebra we know that a polynomial of degree $n$ can have at most $n$ roots, unless it is the zero. Therefore we must have that $\|q\|=0$ implies $q=0$.
#
# *Homogenity*
# $$
# \begin{align}
# \|\alpha q\|_P &= \sum_{k=0}^n|\alpha q(x_k)| = \sum_{k=0}^n|\alpha|| q(x_k)|= |\alpha|\sum_{k=0}^n| q(x_k)| = |\alpha|\|q\|
# \end{align}
# $$
#
# *Triangle inequality*
# $$
# \begin{align}
# \|p +q\|_P &= \sum_{k=0}^n|(p  + q)(x_k)| = \sum_{k=0}^n|p(x_k)+ q(x_k)|\leq \sum_{k=0}^n(| p(x_k)|+| q(x_k)|) = \sum_{k=0}^n| p(x_k)| + \sum_{k=0}^n| q(x_k)| = \|p\| + \|q\|
# \end{align}
# $$
#
# Thus the norm axioms holds for any $p,q$, so the norm $\|\,.\|_P$ is a norm on $\mathbb{P}_n(\mathbb{R})$.

# %% [markdown]
# ### f)
# We now define
# $$
# \|q\|_{C^n} := \max_{0\leq j \leq n}|q^{(j)}(0)|
# $$
# where $$q^{(j)} = \dfrac{d^jq}{dx^q}.$$
#
# Show that $\|\cdot\|_{C^n}$ is also a norm on $\mathbb{P}_n(\mathbb{R})$.
#
# <font color ='blue'>
#     Solution:
#
# </font>

# %% [markdown]
# If we write the polynomial as $q(x) = c_0 + c_1x + c_2x^2 + ...+ c_nx^n$, we see that the norm can be written as
# $$
# \|q\|_{C^n} := \max_{0\leq j \leq n}|q^{(j)}(0)| = \max_{0\leq j \leq n}|j! c_j|
# $$
